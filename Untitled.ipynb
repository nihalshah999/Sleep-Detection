# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.rcParams["figure.figsize"] = 15, 7

# %%
train_df = pd.read_parquet("child-mind-institute-detect-sleep-states/train_series.parquet")
train_df
# Out:
#               series_id    step                 timestamp     anglez    enmo
# 0          038441c925bb       0  2018-08-14T15:30:00-0400   2.636700  0.0217
# 1          038441c925bb       1  2018-08-14T15:30:05-0400   2.636800  0.0215
# 2          038441c925bb       2  2018-08-14T15:30:10-0400   2.637000  0.0216
# 3          038441c925bb       3  2018-08-14T15:30:15-0400   2.636800  0.0213
# 4          038441c925bb       4  2018-08-14T15:30:20-0400   2.636800  0.0215
# ...                 ...     ...                       ...        ...     ...
# 127946335  fe90110788d2  592375  2017-09-08T00:14:35-0400 -27.277500  0.0204
# 127946336  fe90110788d2  592376  2017-09-08T00:14:40-0400 -27.032499  0.0233
# 127946337  fe90110788d2  592377  2017-09-08T00:14:45-0400 -26.841200  0.0202
# 127946338  fe90110788d2  592378  2017-09-08T00:14:50-0400 -26.723900  0.0199
# 127946339  fe90110788d2  592379  2017-09-08T00:14:55-0400 -31.521601  0.0205
#
# [127946340 rows x 5 columns]

# %%
train_df[train_df["series_id"] == "038441c925bb"]
# Out:
#            series_id    step                 timestamp     anglez    enmo
# 0       038441c925bb       0  2018-08-14T15:30:00-0400   2.636700  0.0217
# 1       038441c925bb       1  2018-08-14T15:30:05-0400   2.636800  0.0215
# 2       038441c925bb       2  2018-08-14T15:30:10-0400   2.637000  0.0216
# 3       038441c925bb       3  2018-08-14T15:30:15-0400   2.636800  0.0213
# 4       038441c925bb       4  2018-08-14T15:30:20-0400   2.636800  0.0215
# ...              ...     ...                       ...        ...     ...
# 389875  038441c925bb  389875  2018-09-06T04:59:35-0400 -27.373899  0.0110
# 389876  038441c925bb  389876  2018-09-06T04:59:40-0400 -27.493799  0.0110
# 389877  038441c925bb  389877  2018-09-06T04:59:45-0400 -27.533701  0.0111
# 389878  038441c925bb  389878  2018-09-06T04:59:50-0400 -28.003599  0.0111
# 389879  038441c925bb  389879  2018-09-06T04:59:55-0400 -28.656700  0.0125
#
# [389880 rows x 5 columns]

# %%
train_df[train_df["series_id"] == "fe90110788d2"]
# Out:
#               series_id    step                 timestamp     anglez    enmo
# 127353960  fe90110788d2       0  2017-08-04T17:30:00-0400 -27.707001  0.0298
# 127353961  fe90110788d2       1  2017-08-04T17:30:05-0400 -33.867500  0.0488
# 127353962  fe90110788d2       2  2017-08-04T17:30:10-0400 -15.475000  0.1077
# 127353963  fe90110788d2       3  2017-08-04T17:30:15-0400 -73.656197  0.0530
# 127353964  fe90110788d2       4  2017-08-04T17:30:20-0400 -53.152901  0.0601
# ...                 ...     ...                       ...        ...     ...
# 127946335  fe90110788d2  592375  2017-09-08T00:14:35-0400 -27.277500  0.0204
# 127946336  fe90110788d2  592376  2017-09-08T00:14:40-0400 -27.032499  0.0233
# 127946337  fe90110788d2  592377  2017-09-08T00:14:45-0400 -26.841200  0.0202
# 127946338  fe90110788d2  592378  2017-09-08T00:14:50-0400 -26.723900  0.0199
# 127946339  fe90110788d2  592379  2017-09-08T00:14:55-0400 -31.521601  0.0205
#
# [592380 rows x 5 columns]

# %%
fig, ax = plt.subplots(2, 1)
ax[0].plot(train_df[train_df["series_id"] == "fe90110788d2"]["anglez"])
ax[0].set_title("anglez")
ax[1].plot(train_df[train_df["series_id"] == "fe90110788d2"]["enmo"])
ax[1].set_title("enmo")
plt.show()

# %%
train_event_df = pd.read_csv("child-mind-institute-detect-sleep-states/train_events.csv")
train_event_df
# Out:
#           series_id  night   event      step                 timestamp
# 0      038441c925bb      1   onset    4992.0  2018-08-14T22:26:00-0400
# 1      038441c925bb      1  wakeup   10932.0  2018-08-15T06:41:00-0400
# 2      038441c925bb      2   onset   20244.0  2018-08-15T19:37:00-0400
# 3      038441c925bb      2  wakeup   27492.0  2018-08-16T05:41:00-0400
# 4      038441c925bb      3   onset   39996.0  2018-08-16T23:03:00-0400
# ...             ...    ...     ...       ...                       ...
# 14505  fe90110788d2     33  wakeup  560604.0  2017-09-06T04:07:00-0400
# 14506  fe90110788d2     34   onset  574620.0  2017-09-06T23:35:00-0400
# 14507  fe90110788d2     34  wakeup  581604.0  2017-09-07T09:17:00-0400
# 14508  fe90110788d2     35   onset       NaN                       NaN
# 14509  fe90110788d2     35  wakeup       NaN                       NaN
#
# [14510 rows x 5 columns]

# %%
train_event_df[train_event_df["series_id"] == "fe90110788d2"]
# Out:
#           series_id  night   event      step                 timestamp
# 14440  fe90110788d2      1   onset       NaN                       NaN
# 14441  fe90110788d2      1  wakeup       NaN                       NaN
# 14442  fe90110788d2      2   onset   21048.0  2017-08-05T22:44:00-0400
# 14443  fe90110788d2      2  wakeup   27852.0  2017-08-06T08:11:00-0400
# 14444  fe90110788d2      3   onset   38064.0  2017-08-06T22:22:00-0400
# ...             ...    ...     ...       ...                       ...
# 14505  fe90110788d2     33  wakeup  560604.0  2017-09-06T04:07:00-0400
# 14506  fe90110788d2     34   onset  574620.0  2017-09-06T23:35:00-0400
# 14507  fe90110788d2     34  wakeup  581604.0  2017-09-07T09:17:00-0400
# 14508  fe90110788d2     35   onset       NaN                       NaN
# 14509  fe90110788d2     35  wakeup       NaN                       NaN
#
# [70 rows x 5 columns]

# %%
test_df = pd.read_parquet("child-mind-institute-detect-sleep-states/test_series.parquet")
test_df
# Out:
#         series_id  step                 timestamp     anglez    enmo
# 0    038441c925bb     0  2018-08-14T15:30:00-0400   2.636700  0.0217
# 1    038441c925bb     1  2018-08-14T15:30:05-0400   2.636800  0.0215
# 2    038441c925bb     2  2018-08-14T15:30:10-0400   2.637000  0.0216
# 3    038441c925bb     3  2018-08-14T15:30:15-0400   2.636800  0.0213
# 4    038441c925bb     4  2018-08-14T15:30:20-0400   2.636800  0.0215
# ..            ...   ...                       ...        ...     ...
# 445  0402a003dae9   145  2018-12-18T12:57:05-0500 -59.696899  0.0601
# 446  0402a003dae9   146  2018-12-18T12:57:10-0500 -35.656601  0.0427
# 447  0402a003dae9   147  2018-12-18T12:57:15-0500 -21.582399  0.0309
# 448  0402a003dae9   148  2018-12-18T12:57:20-0500 -42.616001  0.0328
# 449  0402a003dae9   149  2018-12-18T12:57:25-0500   7.029900  0.0081
#
# [450 rows x 5 columns]

# %%
fig, ax = plt.subplots(2, 1)
ax[0].plot(test_df[test_df["series_id"] == "038441c925bb"]["anglez"])
ax[0].set_title("anglez")
ax[1].plot(test_df[test_df["series_id"] == "038441c925bb"]["enmo"])
ax[1].set_title("enmo")
plt.show()

# %%
submission_df = pd.read_csv("child-mind-institute-detect-sleep-states/sample_submission.csv")
submission_df
# Out:
#    row_id     series_id  step   event  score
# 0       0  038441c925bb   100   onset    0.0
# 1       1  038441c925bb   105  wakeup    0.0
# 2       2  03d92c9f6f8a    80   onset    0.5
# 3       3  03d92c9f6f8a   110  wakeup    0.5
# 4       4  0402a003dae9    90   onset    1.0
# 5       5  0402a003dae9   120  wakeup    1.0
